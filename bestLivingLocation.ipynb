# %%
import pandas as pd

# %%
# %run -i 'stateLivingComparison.py'
# Out:
# <div>
#
#
#             <div id="a72e9698-9caa-4f48-8beb-3ac67df2c296" class="plotly-graph-div" style="height:450px; width:900px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("a72e9698-9caa-4f48-8beb-3ac67df2c296")) {
#                     Plotly.newPlot(
#                         'a72e9698-9caa-4f48-8beb-3ac67df2c296',
# ...
