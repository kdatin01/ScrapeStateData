# %%
import pandas as pd

# %%
# %run -i 'stateLivingComparison.py'
# Out:
# <div>
#
#
#             <div id="18157f37-b01c-4aa1-9577-f1aa43d43b2a" class="plotly-graph-div" style="height:450px; width:900px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("18157f37-b01c-4aa1-9577-f1aa43d43b2a")) {
#                     Plotly.newPlot(
#                         '18157f37-b01c-4aa1-9577-f1aa43d43b2a',
# ...
